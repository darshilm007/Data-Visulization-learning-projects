# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

data = {
    'Department': ['IT', 'IT', 'IT', 'HR', 'HR', 'Finance', 'Finance', 'Finance'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male'],
    'Age': [25, 28, 35, 30, 45, 40, 38, 50],
    'Salary': [60000, 65000, 80000, 48000, 52000, 70000, 72000, 90000]
}

df = pd.DataFrame(data)

"""1️⃣ Salary Distribution by Department

Use a box plot

X → Department

Y → Salary"""

fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle("Employee Analytics Dashboard", fontsize=16)


sns.boxplot(
    x='Department',
    y='Salary',
    data=df,
    ax=axes[0]
)
axes[0].set_title("Salary Distribution by Department")
axes[0].set_xlabel("Department")
axes[0].set_ylabel("Salary")


"""2️⃣ Average Salary by Department

Use a bar plot

X → Department

Y → Average Salary"""

avg_salary = df.groupby('Department')['Salary'].mean().reset_index()

sns.barplot(x=grp.index, y=grp.values,data=avg_salary,ax=axes[1])
axes[1].set_title("Average Salary by Department")
axes[0].set_xlabel("Department")
axes[0].set_ylabel("Salary")
"""
3️⃣ Age Distribution of Employees

Use a histogram"""



sns.histplot(x='Age',data=df,bins=5,ax=axes[2])
axes[2].set_title("Age Distribution of Employees")
axes[2].set_xlabel("Age")
axes[2].set_ylabel("Count")
plt.tight_layout()
plt.show()
